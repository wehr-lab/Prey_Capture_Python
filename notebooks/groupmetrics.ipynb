# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
csv='/Volumes/molly/mollys_finished_hell.csv'

# %%
df=pd.read_csv(csv)

# %%
df
# Out:
#      Unnamed: 0                                           filename  \
# 0             0  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 1             1  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 2             2  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 3             4  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 4             5  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# ..          ...                                                ...
# 200         328  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 201         329  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 202         330  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 203         331  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 204         332  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
#
#                                            folder_path   condition  \
# 0    /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...  Condition1
# ...

# %%
df0896=df[df['filename'].str.contains('0896')]
df0896
# Out:
#      Unnamed: 0                                           filename  \
# 0             0  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 1             1  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 2             2  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 3             4  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 4             5  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# ..          ...                                                ...
# 173         288  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 174         289  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 175         290  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 176         291  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 177         292  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
#
#                                            folder_path   condition  \
# 0    /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...  Condition1
# ...

# %%
plt.figure(figsize=(8,8))
ax=sns.barplot(data=df0896, x='condition', y='captureT', hue='laser_value', ci=68, palette="colorblind")
ax= sns.swarmplot(x='condition', y='captureT', hue='laser_value',dodge=True, data=df0896, color='gray', size=3.5)
# plt.ylim(0,50)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0896lightcaptureTbar.pdf')

# %%
plt.figure(figsize=(8,8))
ax=sns.boxplot(data=df0896, x='condition', y='captureT', hue='laser_value', palette="colorblind")
# ax= sns.swarmplot(x='condition', y='captureT', hue='laser_value',dodge=True, data=df0896, color='gray', size=3.5)
# plt.ylim(0,50)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0896lightcaptureTbox.pdf')

# %%
df0897=df[df['filename'].str.contains('0897')]
# df0897

# %%
plt.figure(figsize=(8,8))
ax=sns.barplot(data=df0897, x='condition', y='captureT', hue='laser_value', ci=68, palette="colorblind")
ax= sns.swarmplot(x='condition', y='captureT', hue='laser_value',dodge=True, data=df0897, color='gray', size=3.5)
# plt.ylim(0,50)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0897lightcaptureTbar.pdf')

# %%
plt.figure(figsize=(8,8))
ax=sns.boxplot(data=df0897, x='condition', y='captureT', hue='laser_value', palette="colorblind")
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0897lightcaptureTbox.pdf')

# %%
df0898=df[df['filename'].str.contains('0898')]
plt.figure(figsize=(8,8))
ax=sns.barplot(data=df0898, x='condition', y='captureT', hue='laser_value', ci=68, palette="colorblind")
ax= sns.swarmplot(x='condition', y='captureT', hue='laser_value',dodge=True, data=df0898, color='gray', size=3.5)
# plt.ylim(0,50)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0898lightcaptureTbar.pdf')

# %%
plt.figure(figsize=(8,8))
ax=sns.boxplot(data=df0898, x='condition', y='captureT', hue='laser_value', palette="colorblind")
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0898lightcaptureTbox.pdf')

# %%
dark_df0898=dark_df[dark_df['filename'].str.contains('0898')]
plt.figure(figsize=(8,8))
ax=sns.barplot(data=dark_df0898, x='condition', y='captureT', hue='laser_value', ci=68, palette="colorblind", alpha=0.75)
ax= sns.swarmplot(x='condition', y='captureT', hue='laser_value',dodge=True, data=dark_df0898, color='gray', size=3.5)
# plt.ylim(0,50)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0898darkcaptureTbar.pdf')

# %%
plt.figure(figsize=(8,8))
ax=sns.boxplot(data=dark_df0898, x='condition', y='captureT', hue='laser_value', palette="colorblind")
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0898darkcaptureTbox.pdf')

# %%
dark_df0897=dark_df[dark_df['filename'].str.contains('0897')]
plt.figure(figsize=(8,8))
ax=sns.barplot(data=dark_df0897, x='condition', y='captureT', hue='laser_value', ci=68, palette="colorblind", alpha=0.75)
ax= sns.swarmplot(x='condition', y='captureT', hue='laser_value',dodge=True, data=dark_df0897, color='gray', size=3.5)
# plt.ylim(0,50)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0897darkcaptureTbar.pdf')

# %%
plt.figure(figsize=(8,8))
ax=sns.boxplot(data=dark_df0897, x='condition', y='captureT', hue='laser_value', palette="colorblind")
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0897darkcaptureTbox.pdf')

# %%
dark_df0896=dark_df[dark_df['filename'].str.contains('0896')]
plt.figure(figsize=(8,8))
ax=sns.barplot(data=dark_df0896, x='condition', y='captureT', hue='laser_value', ci=68, palette="colorblind", alpha=0.75)
ax= sns.swarmplot(x='condition', y='captureT', hue='laser_value',dodge=True, data=dark_df0896, color='gray', size=3.5)
# plt.ylim(0,50)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0896darkcaptureTbar.pdf')

# %%
plt.figure(figsize=(8,8))
ax=sns.boxplot(data=dark_df0896, x='condition', y='captureT', hue='laser_value', palette="colorblind")
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/0896darkcaptureTbox.pdf')

# %%
mean_df=df.groupby(['condition','laser_value']).mean()
# mean_df['condtion'] = mean_df.index
mean_df=mean_df.reset_index()

# %%
mean_df
# Out:
#     condition  laser_value  Unnamed: 0   captureT  freqapproach  \
# 0  Condition1            0   45.766667  29.265431      0.152493
# 1  Condition1            1  151.750000  13.522368      0.123834
# 2  Condition2            0  244.697674  29.930000      0.128516
# 3  Condition2            1  304.571429  14.252051      0.134766
#
#    timetoapproach  prob_inter  prob_capture  Unnamed: 14  Unnamed: 15  \
# 0        2.477931    0.656515      0.450472          NaN          NaN
# 1        2.761404    0.746675      0.511195   356.503333     0.094974
# 2        2.058488    0.738829      0.496840          NaN          NaN
# 3        1.197308    0.768498      0.412312   261.612500     0.098733
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18
# 0          NaN          NaN          NaN
# 1     6.666667     0.273925     0.166667
# 2          NaN          NaN          NaN
# 3    10.085000     0.357143     0.205128

# %%
sem_df=df.groupby(['condition','laser_value']).sem()

# %%
sem_df
# Out:
#                         Unnamed: 0   captureT  freqapproach  timetoapproach  \
# condition  laser_value
# Condition1 0              3.855539   6.314349      0.008811        0.568590
#            1              3.837492   9.858484      0.007994        0.405845
# Condition2 0              2.657140  10.282475      0.012550        0.341315
#            1              2.718104   9.426225      0.010331        0.530213
#
#                         prob_inter  prob_capture
# condition  laser_value
# Condition1 0              0.034061      0.040486
#            1              0.033463      0.043807
# Condition2 0              0.039578      0.051823
#            1              0.040669      0.043223

# %%
mean_df.plot.bar( y='timetoapproach')
# Out:
# <AxesSubplot:xlabel='condition,laser_value'>

# %%
plt.figure(figsize=(8,8))
ax=sns.barplot(data=df, x='condition', y='captureT', hue='laser_value', ci=68, palette="colorblind")
ax= sns.swarmplot(x='condition', y='captureT', hue='laser_value',dodge=True, data=df, color='gray', size=3.5)
# plt.ylim(0,150)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/all_lightcaptureTbar.pdf')

# %%
plt.figure(figsize=(8,8))
ax=sns.boxplot(data=dark_df, x='condition', y='captureT', hue='laser_value', palette="colorblind")
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/all_darkcaptureTbox.pdf')

# %%
plt.figure(figsize=(8,8))
ax=sns.barplot(data=df, x='condition', y='timetoapproach', hue='laser_value', ci=68, palette="colorblind")
ax= sns.swarmplot(x='condition', y='timetoapproach', hue='laser_value',dodge=True, data=df, color='gray', size=3.5)
# plt.ylim(0,8)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/all_lightlatencybar.pdf')

# %%
plt.figure(figsize=(8,8))
ax=sns.boxplot(data=df, x='condition', y='timetoapproach', hue='laser_value', palette="colorblind")
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/all_lightlatencybox.pdf')

# %%
sns.barplot(data=df, x='condition', y='freqapproach', hue='laser_value', ci=95, palette="colorblind")
plt.ylim(0,0.2)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ProposalExam/Figures/freqapproach_light.pdf')

# %%
sns.barplot(data=df, x='condition', y='prob_inter', hue='laser_value', ci=95, palette="colorblind")
plt.ylim(0,1)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ProposalExam/Figures/probinter_light.pdf')

# %%
sns.barplot(data=df, x='condition', y='prob_capture', hue='laser_value', ci=95, palette="colorblind")
plt.ylim(0,1)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ProposalExam/Figures/probcap_light.pdf')

# %%
csv='/Volumes/molly/mollys_finished_hell_dark.csv'
dark_df=pd.read_csv(csv)

# %%
dark_df
# Out:
#      Unnamed: 0                                           filename  \
# 0             0  /mnt/ion-nas/Rig4/Molly/2022-03-03_9-38-57_mou...
# 1             1  /mnt/ion-nas/Rig4/Molly/2022-03-04_10-03-58_mo...
# 2             2  /mnt/ion-nas/Rig4/Molly/2022-03-04_9-50-19_mou...
# 3             3  /mnt/ion-nas/Rig4/Molly/2022-03-04_9-52-07_mou...
# 4             4  /mnt/ion-nas/Rig4/Molly/2022-03-04_9-53-53_mou...
# ..          ...                                                ...
# 201         218  /mnt/ion-nas/Rig4/Molly/2022-04-14_12-31-38_mo...
# 202         220  /mnt/ion-nas/Rig4/Molly/2022-04-15_9-26-51_mou...
# 203         221  /mnt/ion-nas/Rig4/Molly/2022-04-15_9-30-48_mou...
# 204         222  /mnt/ion-nas/Rig4/Molly/2022-04-15_9-34-46_mou...
# 205         223  /mnt/ion-nas/Rig4/Molly/2022-04-15_9-37-48_mou...
#
#                                            folder_path   condition  \
# 0    /mnt/ion-nas/Rig4/Molly/2022-03-03_9-38-57_mou...  Condition1
# ...

# %%
mean_dark_df=dark_df.groupby(['condition','laser_value']).mean()
mean_dark_df
# Out:
#                         Unnamed: 0   captureT  freqapproach  timetoapproach  \
# condition  laser_value
# Condition1 0             27.075472  18.169038      0.122481        2.316442
#            1             81.957447  16.215682      0.121786        1.831136
# Condition2 0            139.537037  16.707264      0.100786        4.766509
#            1            194.826923  11.586633      0.098634        2.549898
#
#                         prob_inter  prob_capture  Unnamed: 14  Unnamed: 15  \
# condition  laser_value
# Condition1 0              0.650407      0.613942          NaN          NaN
#            1              0.650730      0.635633      193.185     0.132541
# Condition2 0              0.696710      0.609037          NaN          NaN
#            1              0.640776      0.665816          NaN          NaN
#
#                         Unnamed: 16  Unnamed: 17  Unnamed: 18
# condition  laser_value
# Condition1 0                    NaN          NaN          NaN
# ...

# %%
plt.figure(figsize=(8,8))
ax= sns.barplot(data=dark_df, x='condition', y='captureT', hue='laser_value', ci=68, palette="colorblind", alpha=0.75)
ax= sns.swarmplot(x='condition', y='captureT', hue='laser_value',dodge=True, data=dark_df, color='gray', size=3.5)
# plt.ylim(0,50)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/all_darkcaptureTbar.pdf')

# %%
plt.figure(figsize=(8,8))
ax= sns.boxplot(data=dark_df, x='condition', y='captureT', hue='laser_value',  palette="colorblind")
sns.despine()

# %%
plt.figure(figsize=(8,5))
ax= sns.ecdfplot(data=dark_df, x='captureT', hue='laser_value',  palette="colorblind")
sns.despine()
# plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ProposalExam/Figures/latency_darkcdf.pdf')

# %%
ax= sns.violinplot(data=dark_df, x='condition', y='timetoapproach',hue='laser_value',  palette="colorblind",split=True)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ProposalExam/Figures/latency_darkviolin_split.pdf')

# %%
ax= sns.violinplot(data=df, x='condition', y='timetoapproach',hue='laser_value',  palette="colorblind",split=True)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ProposalExam/Figures/latency_lightviolin_split.pdf')

# %%
plt.figure(figsize=(8,8))
ax= sns.histplot(data=dark_df, x='timetoapproach', hue='laser_value',  kde=True,palette="colorblind", alpha=0.75,multiple='dodge')
sns.despine()

# %%
plt.figure(figsize=(8,5))
ax= sns.ecdfplot(data=df, x='captureT', hue='laser_value',  palette="colorblind")
sns.despine()
# plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ProposalExam/Figures/latency_lightcdf.pdf')

# %%
ax= sns.histplot(data=df, x='timetoapproach', hue='laser_value',  kde=True,palette="colorblind", alpha=.8,multiple='dodge')
sns.despine()

# %%
plt.figure(figsize=(8,8))
ax=sns.barplot(data=dark_df, x='condition', y='timetoapproach', hue='laser_value', ci=68, palette="colorblind",alpha=0.75)
ax= sns.swarmplot(x='condition', y='timetoapproach', hue='laser_value',dodge=True, data=dark_df, color='gray', size=2.5)
plt.ylim(0,25)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/all_darklatencybar25.pdf')

# %%
plt.figure(figsize=(8,8))
ax=sns.boxplot(data=dark_df, x='condition', y='timetoapproach', hue='laser_value', palette="colorblind")
sns.despine()
plt.ylim(0,25)
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/all_darklatencybox25.pdf')

# %%
sns.barplot(data=dark_df, x='condition', y='freqapproach', hue='laser_value', ci=68, palette="colorblind",alpha=0.75)
plt.ylim(0,0.2)
sns.despine()
# plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ProposalExam/Figures/freqapproach_dark.pdf')

# %%
sns.barplot(data=dark_df, x='condition', y='prob_inter', hue='laser_value', ci=95, palette="colorblind",alpha=0.75)
plt.ylim(0,1)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ProposalExam/Figures/probinter_dark.pdf')

# %%
sns.barplot(data=dark_df, x='condition', y='prob_capture', hue='laser_value', ci=95, palette="colorblind",alpha=0.75)
plt.ylim(0,1)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ProposalExam/Figures/probcap_dark.pdf')

# %%
sns.jointplot(data=df, x='captureT', y='timetoapproach', hue='laser_value')

# %%
test=df['mouse_spd']
test[0]
# Out:
# '[14.012931903926157 16.45841103998438 19.1850469208259 ...\n 0.34091196709256927 0.25562491173099033 0.5360731057000628]'

# %%
t=test[1:-1]

# %%
import numpy as np

# %%
len(t)
# Out:
# 117

# %%
t
# Out:
# '14.012931903926157 16.45841103998438 19.1850469208259 ...\n 0.34091196709256927 0.25562491173099033 0.5360731057000628'

# %%
test_list=list(map(float,t.split()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-259-c88039d1b152> in <module>
# ----> 1 test_list=list(map(float,t.split()))
#
# ValueError: could not convert string to float: '...'

# %%
test_list
# Out:
# ['14.012931903926157',
#  '16.45841103998438',
#  '19.1850469208259',
#  '...',
#  '0.34091196709256927',
#  '0.25562491173099033',
#  '0.5360731057000628']

# %%
len(test_list)
# Out:
# 7

# %%
all_df=pd.concat([df, dark_df])

# %%
all_df
# Out:
#      Unnamed: 0                                           filename  \
# 0             0  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 1             1  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 2             2  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 3             4  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# 4             5  /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...
# ..          ...                                                ...
# 201         218  /mnt/ion-nas/Rig4/Molly/2022-04-14_12-31-38_mo...
# 202         220  /mnt/ion-nas/Rig4/Molly/2022-04-15_9-26-51_mou...
# 203         221  /mnt/ion-nas/Rig4/Molly/2022-04-15_9-30-48_mou...
# 204         222  /mnt/ion-nas/Rig4/Molly/2022-04-15_9-34-46_mou...
# 205         223  /mnt/ion-nas/Rig4/Molly/2022-04-15_9-37-48_mou...
#
#                                            folder_path   condition  \
# 0    /mnt/rig4/lab/djmaus/Data/Molly/ZIActivation/2...  Condition1
# ...

# %%
plt.figure(figsize=(8,8))
# ax=sns.boxplot(data=df, x='condition', y='captureT', hue='laser_value', palette="colorblind")
ax1=sns.boxplot(data=dark_df, x='condition', y='captureT', hue='laser_value', palette='colorblind')
plt.ylim(0,350)
sns.despine()
plt.savefig('/Users/mollyshallow/Desktop/Wehr_Lab/ZIActivationPlots/all_darkcaptureTbox350.pdf')
