# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np
from copy import deepcopy as cdc

from datetime import datetime as dt
import re
def extract_timestamps(series:pd.Series) -> pd.Series:
    timestamp = series.str.extract('_(\d{4}-[\-\d_T]*)DLC', expand=False)
    return pd.to_datetime(timestamp, format="%Y-%m-%dT%H_%M_%S")
##need to have filename column as type str in order for datetime extraction to be used, won't run on Posix type

import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats

import prey_capture_python as preycap
# import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv='/Volumes/Projects/PreyCapture/ZIActivation/DataDirs_test2.csv'

# %%
tracking=pd.read_csv(csv)

# %%
tracking
# Out:
#                                                    path  Cond  FatalFlag  \
# 0     /Volumes/Projects/PreyCapture/ZIActivation/202...  test        NaN
# 1     /Volumes/Projects/PreyCapture/ZIActivation/202...  test        NaN
# 2     /Volumes/Projects/PreyCapture/ZIActivation/202...  test        NaN
# 3     /Volumes/Projects/PreyCapture/ZIActivation/202...  test        NaN
# 4     /Volumes/Projects/PreyCapture/ZIActivation/202...  test        NaN
# ...                                                 ...   ...        ...
# 4095  /Volumes/Projects/PreyCapture/ZIActivation/202...     9        NaN
# 4096  /Volumes/Projects/PreyCapture/ZIActivation/202...     9        NaN
# 4097  /Volumes/Projects/PreyCapture/ZIActivation/202...     9        NaN
# 4098  /Volumes/Projects/PreyCapture/ZIActivation/202...     9        NaN
# 4099  /Volumes/Projects/PreyCapture/ZIActivation/202...     9        NaN
#
#       Laser       dlc
# 0       NaN     track
# 1       NaN     track
# ...

# %%
tracking['path']=tracking['path'].astype('str')
# type(df_all['filename'][0])
newmice=tracking[tracking['path'].str.contains('1337|1429|1430')]

# %%
newmice
# Out:
#                                                    path  Cond  FatalFlag  \
# 2800  /Volumes/Projects/PreyCapture/ZIActivation/202...  test        NaN
# 2801  /Volumes/Projects/PreyCapture/ZIActivation/202...  test        NaN
# 2802  /Volumes/Projects/PreyCapture/ZIActivation/202...  test        NaN
# 2803  /Volumes/Projects/PreyCapture/ZIActivation/202...  test        NaN
# 2804  /Volumes/Projects/PreyCapture/ZIActivation/202...  test        NaN
# ...                                                 ...   ...        ...
# 4095  /Volumes/Projects/PreyCapture/ZIActivation/202...     9        NaN
# 4096  /Volumes/Projects/PreyCapture/ZIActivation/202...     9        NaN
# 4097  /Volumes/Projects/PreyCapture/ZIActivation/202...     9        NaN
# 4098  /Volumes/Projects/PreyCapture/ZIActivation/202...     9        NaN
# 4099  /Volumes/Projects/PreyCapture/ZIActivation/202...     9        NaN
#
#       Laser       dlc
# 2800    0.0       NaN
# 2801    0.0       NaN
# ...

# %%
notrack=newmice.iloc[np.where(newmice['dlc']=='no track')]
track=newmice.iloc[np.where(newmice['dlc']=='track')]

# %%
notrack
# Out:
#                                                    path Cond  FatalFlag  \
# 3420  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3422  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3423  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3424  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3427  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# ...                                                 ...  ...        ...
# 4095  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 4096  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 4097  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 4098  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 4099  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
#
#       Laser       dlc
# 3420    0.0  no track
# 3422    1.0  no track
# 3423    0.0  no track
# ...

# %%
track
# Out:
#                                                    path Cond  FatalFlag  \
# 3421  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3425  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3426  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3428  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3434  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# ...                                                 ...  ...        ...
# 3747  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3751  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3766  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3768  /Volumes/Projects/PreyCapture/ZIActivation/202...    6        NaN
# 3771  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
#
#       Laser    dlc
# 3421    1.0  track
# 3425    1.0  track
# 3426    0.0  track
# 3428    0.0  track
# ...

# %%
cond1=notrack.iloc[np.where(notrack['Cond']=='1')]
cond2=notrack.iloc[np.where(notrack['Cond']=='2')]
cond9=notrack.iloc[np.where(notrack['Cond']=='9')]

# %%
cond1
# Out:
#                                                    path Cond  FatalFlag  \
# 3420  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3422  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3423  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3424  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3427  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3429  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3456  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3458  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3460  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3462  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3477  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# 3478  /Volumes/Projects/PreyCapture/ZIActivation/202...    1        NaN
# ...

# %%
np.size(np.where(cond1['Laser']==0))
# Out:
# 26

# %%
np.size(np.where(cond1['Laser']==1))
# Out:
# 24

# %%
cond2
# Out:
#                                                    path Cond  FatalFlag  \
# 3432  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3433  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3441  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3772  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3773  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3774  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3777  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3778  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3779  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3780  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3781  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# 3782  /Volumes/Projects/PreyCapture/ZIActivation/202...    2        NaN
# ...

# %%
len(cond2)
# Out:
# 33

# %%
np.size(np.where(cond2['Laser']==0))
# Out:
# 17

# %%
np.size(np.where(cond2['Laser']==1))
# Out:
# 16

# %%
cond9
# Out:
#                                                    path Cond  FatalFlag  \
# 3834  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 3835  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 3836  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 3837  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 3838  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# ...                                                 ...  ...        ...
# 4095  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 4096  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 4097  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 4098  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
# 4099  /Volumes/Projects/PreyCapture/ZIActivation/202...    9        NaN
#
#       Laser       dlc
# 3834    0.0  no track
# 3835    1.0  no track
# 3836    0.0  no track
# ...

# %%
np.size(np.where(cond9['Laser']==0))
# Out:
# 89

# %%
np.size(np.where(cond9['Laser']==1))
# Out:
# 90
